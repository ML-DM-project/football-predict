# %% [markdown]
# ## Target: Create multiple csv file contains features from ...statistic.json, matches.json, ...

# %% [markdown]
# ### 1. From matches.json

# %%
import json

# %%
with open("EPL 23-24\\2023_11_07\\matches.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# %%
for obj in data["events"]:
    if obj["tournament"]["id"] == 1:
        print(obj)
# Out:
# {'tournament': {'name': 'Premier League', 'id': 1}, 'roundInfo': {'round': 11}, 'status': {'code': 100, 'description': 'Ended', 'type': 'finished'}, 'homeTeam': {'name': 'Tottenham Hotspur', 'slug': 'tottenham-hotspur', 'shortName': 'Tottenham ', 'type': 0, 'id': 33, 'country': {'alpha2': 'EN', 'name': 'England'}}, 'awayTeam': {'name': 'Chelsea', 'slug': 'chelsea', 'shortName': 'Chelsea', 'type': 0, 'id': 38, 'country': {'alpha2': 'EN', 'name': 'England'}}, 'homeScore': {'current': 1, 'display': 1, 'period1': 1, 'period2': 0, 'normaltime': 1}, 'awayScore': {'current': 4, 'display': 4, 'period1': 1, 'period2': 3, 'normaltime': 4}, 'id': 11352323, 'startTimestamp': 1699300800, 'endTimestamp': 1699305301, 'slug': 'chelsea-tottenham-hotspur'}

# %%
import glob

for file in glob.glob("EPL 23-24\\*\\matches.json"):
    print(file)
# Out:
# EPL 23-24\2023_08_12\matches.json
# EPL 23-24\2023_08_13\matches.json
# EPL 23-24\2023_08_15\matches.json
# EPL 23-24\2023_08_19\matches.json
# EPL 23-24\2023_08_22\matches.json
# EPL 23-24\2023_08_26\matches.json
# EPL 23-24\2023_09_02\matches.json
# EPL 23-24\2023_09_16\matches.json
# EPL 23-24\2023_09_17\matches.json
# EPL 23-24\2023_09_19\matches.json
# EPL 23-24\2023_09_23\matches.json
# EPL 23-24\2023_09_30\matches.json
# EPL 23-24\2023_10_01\matches.json
# EPL 23-24\2023_10_03\matches.json
# EPL 23-24\2023_10_07\matches.json
# EPL 23-24\2023_10_21\matches.json
# EPL 23-24\2023_10_22\matches.json
# EPL 23-24\2023_10_24\matches.json
# EPL 23-24\2023_10_28\matches.json
# EPL 23-24\2023_10_29\matches.json
# EPL 23-24\2023_11_04\matches.json
# EPL 23-24\2023_11_05\matches.json
# EPL 23-24\2023_11_07\matches.json

# %%
for file in glob.glob("EPL 23-24\\*\\matches.json"):
    with open(file, "r", encoding="utf-8") as f:
        data = json.load(f)
        for obj in data["events"]:
            if obj["tournament"]["id"] == 1 and obj["status"]["code"] == 100:
                print(obj["id"], obj["homeTeam"]["id"], obj["awayTeam"]["id"], 
                      obj["homeScore"]["period1"], obj["homeScore"]["current"],
                      obj["awayScore"]["period1"], obj["homeScore"]["current"])
# Out:
# 11352303 6 17 0 0 2 0
# 11352251 42 14 2 2 0 2
# 11352250 60 37 0 1 0 1
# 11352252 30 72 1 4 0 4
# 11352253 48 43 0 0 0 0
# 11352254 15 7 0 0 0 0
# 11352255 39 40 2 5 1 5
# 11352309 50 33 2 2 2 2
# 11352251 42 14 2 2 0 2
# 11352250 60 37 0 1 0 1
# 11352252 30 72 1 4 0 4
# 11352253 48 43 0 0 0 0
# 11352254 15 7 0 0 0 0
# 11352255 39 40 2 5 1 5
# 11352309 50 33 2 2 2 2
# 11352316 38 44 1 1 1 1
# 11352327 35 3 0 1 0 1
# 11352399 14 15 1 2 0 2
# 11352358 43 50 0 0 1 0
# 11352367 44 60 2 3 1 3
# 11352428 3 30 0 1 1 1
# 11352407 33 35 0 2 0 2
# 11352389 17 39 1 1 0 1
# 11352337 40 48 2 4 0 4
# 11352346 7 42 0 0 0 0
# 11352484 38 72 1 3 0 3
# 11352437 60 33 0 0 1 0
# 11352447 42 43 0 2 1 2
# 11352456 50 7 1 1 0 1
# 11352495 48 3 0 0 0 0
# 11352504 35 14 1 3 2 3
# 11352466 30 37 0 1 1 1
# 11352475 6 40 0 1 2 1
# 11352524 15 17 0 1 0 1
# 11352590 72 37 0 1 1 1
# 11352597 15 48 2 2 1 2
# 11352543 50 60 1 2 1 2
# 11352561 6 33 1 2 2 2
# 11352570 38 14 0 0 0 0
# 11352594 17 43 2 5 1 5
# 11352551 30 39 1 3 0 3
# 11352578 7 3 0 3 0 3
# 11352584 44 40 2 3 0 3
# 11352626 3 44 1 1 0 1
# 11352602 40 7 0 3 0 3
# 11352608 43 72 0 1 0 1
# 11352611 35 30 0 1 1 1
# 11352621 33 15 0 2 0 2
# 11352625 37 17 1 1 0 1
# 11352615 39 50 0 1 0 1
# 11352600 60 38 0 0 0 0
# 11352602 40 7 0 3 0 3
# 11352608 43 72 0 1 0 1
# 11352611 35 30 0 1 1 1
# 11352621 33 15 0 2 0 2
# 11352625 37 17 1 1 0 1
# 11352615 39 50 0 1 0 1
# 11352600 60 38 0 0 0 0
# 11352605 48 42 0 0 0 0
# 11352618 14 6 0 1 1 1
# 11352632 7 43 0 0 0 0
# 11352634 72 3 0 1 0 1
# 11352635 17 14 2 2 0 2
# 11352628 50 48 1 1 1 1
# 11352630 6 35 0 0 1 0
# 11352627 42 33 1 2 1 2
# 11352629 30 60 1 3 1 3
# 11352631 38 40 0 0 0 0
# 11352633 44 37 1 3 1 3
# 11352638 40 30 3 6 0 6
# 11352637 60 42 0 0 2 0
# 11352639 48 72 1 1 2 1
# 11352641 35 7 0 0 1 0
# 11352642 39 6 1 2 0 2
# 11352645 37 15 2 2 0 2
# 11352646 3 17 1 2 0 2
# 11352644 33 44 1 2 1 2
# 11352643 14 50 0 1 0 1
# 11352637 60 42 0 0 2 0
# 11352639 48 72 1 1 2 1
# 11352641 35 7 0 0 1 0
# 11352642 39 6 1 2 0 2
# 11352645 37 15 2 2 0 2
# 11352646 3 17 1 2 0 2
# 11352644 33 44 1 2 1 2
# 11352643 14 50 0 1 0 1
# 11352640 43 38 0 0 2 0
# 11626262 72 6 0 1 1 1
# 11352653 72 33 0 0 0 0
# 11352649 6 38 1 1 1 1
# 11352651 48 60 2 3 0 3
# 11352652 43 15 0 3 0 3
# 11352654 35 50 0 2 1 2
# 11352650 7 14 0 0 0 0
# 11352648 30 44 1 2 2 2
# 11352655 37 39 1 2 0 2
# 11352656 3 40 0 1 0 1
# 11352662 44 48 0 2 0 2
# 11352657 60 3 1 1 0 1
# 11352660 50 6 1 3 0 3
# 11352663 17 30 2 2 0 2
# 11352664 39 7 3 4 0 4
# 11352665 14 72 0 2 0 2
# 11352661 38 42 1 2 0 2
# 11352666 15 35 1 1 1 1
# 11352657 60 3 1 1 0 1
# 11352660 50 6 1 3 0 3
# 11352663 17 30 2 2 0 2
# 11352664 39 7 3 4 0 4
# 11352665 14 72 0 2 0 2
# 11352661 38 42 1 2 0 2
# 11352666 15 35 1 1 1 1
# 11352658 40 37 1 4 0 4
# 11352667 33 43 1 2 0 2
# 11352673 7 33 0 1 0 1
# 11352672 38 50 0 0 0 0
# 11352669 42 15 1 5 0 5
# 11352668 60 6 1 2 1 2
# 11352677 3 39 1 2 2 2
# 11352676 37 48 0 0 0 0
# 11352669 42 15 1 5 0 5
# 11352668 60 6 1 2 1 2
# 11352677 3 39 1 2 2 2
# 11352676 37 48 0 0 0 0
# 11352670 40 72 1 3 0 3
# 11352671 30 43 1 1 0 1
# 11352674 44 14 2 3 0 3
# 11352675 35 17 0 0 1 0
# 11352307 43 35 0 0 0 0
# 11352304 50 37 1 3 2 3
# 11352305 6 7 0 0 1 0
# 11352306 48 30 1 1 0 1
# 11352312 17 60 3 6 0 6
# 11352320 15 3 0 2 0 2
# 11352314 39 42 0 1 0 1
# 11352307 43 35 0 0 0 0
# 11352304 50 37 1 3 2 3
# 11352305 6 7 0 0 1 0
# 11352306 48 30 1 1 0 1
# 11352312 17 60 3 6 0 6
# 11352320 15 3 0 2 0 2
# 11352314 39 42 0 1 0 1
# 11352317 14 40 1 2 0 2
# 11352310 72 44 0 1 0 1
# 11352323 33 38 1 1 1 1

# %%
import pandas as pd

dictionary = {
    "id": [],
    "homeTeamId": [],
    "awayTeamId": [],
    "homeScorePeriod1": [],
    "homeScoreCurrent": [],
    "awayScorePeriod1": [],
    "awayScoreCurrent": []
}

df = pd.DataFrame(dictionary)

for file in glob.glob("EPL 23-24\\*\\matches.json"):
    with open(file, "r", encoding="utf-8") as f:
        data = json.load(f)
        for obj in data["events"]:
            if obj["tournament"]["id"] == 1 and obj["status"]["code"] == 100:
                info = [obj["id"], obj["homeTeam"]["id"], obj["awayTeam"]["id"], 
                      obj["homeScore"]["period1"], obj["homeScore"]["current"],
                      obj["awayScore"]["period1"], obj["homeScore"]["current"]]
                df.loc[len(df)] = info
                
df
# Out:
#            id  homeTeamId  awayTeamId  homeScorePeriod1  homeScoreCurrent  \
# 0    11352303           6          17                 0                 0
# 1    11352251          42          14                 2                 2
# 2    11352250          60          37                 0                 1
# 3    11352252          30          72                 1                 4
# 4    11352253          48          43                 0                 0
# ..        ...         ...         ...               ...               ...
# 140  11352320          15           3                 0                 2
# 141  11352314          39          42                 0                 1
# 142  11352317          14          40                 1                 2
# 143  11352310          72          44                 0                 1
# 144  11352323          33          38                 1                 1
#
#      awayScorePeriod1  awayScoreCurrent
# 0                   2                 0
# 1                   0                 2
# 2                   0                 1
# 3                   0                 4
# 4                   0                 0
# ..                ...               ...
# 140                 0                 2
# 141                 0                 1
# 142                 0                 2
# 143                 0                 1
# 144                 1                 1
#
# [145 rows x 7 columns]

# %%
df.to_csv('match_result.csv', index=False)

# %% [markdown]
# ### 2. From statistic.json

# %%
import re
import glob
import pandas as pd
import json

dictionary = {
    "id": [],
    "homeExpectedGoal": [],
    "awayExpectedGoal": [],
    "homeExpectedAssist": [],
    "awayExpectedAssist": [],
    "homeBallPosession": [],   # Only home, away = 1 - home
    "homeShotOnTarget": [],
    "awayShotOnTarget": [],
    "homeShotOffTarget": [],
    "awayShotOffTarget": [],
    "homeBlockedShot": [],
    "awayBlockedShot": [],
    "homeCorner": [],
    "awayCorner": [],
    "homeOffside": [],
    "awayOffside": [],
    "homeFoul": [],
    "awayFoul": [],
    "homeYellowCard": [],
    "awayYellowCard": [],
    "homeRedCard": [],
    "awayRedCard": [],
    "homeFreekick": [],
    "awayFreekick": [],
    "homeThrowIn": [],
    "awayThrowIn": [],
    "homeGoalkick": [],
    "awayGoalkick": [],
    "homeBigChance": [],
    "awayBigChance": [],
    "homeBigChanceMissed": [],
    "awayBigChanceMissed": [],
    "homeShotInsideBox": [],
    "awayShotInsideBox": [],   # shot outside = shot on + shot off - shot inside
    "homeGoalSave": [],
    "awayGoalSave": [],
    "homeGoalPrevented": [],
    "awayGoalPrevented": [],
    "homePass": [],
    "awayPass": [],
    "homeAccuratePass": [],
    "awayAccuratePass": [],
    "homeLongPass": [],
    "awayLongPass": [],
    "homeAccurateLongPass": [],
    "awayAccurateLongPass": [],
    "homeCross": [],
    "awayCross": [],
    "homeAccurateCross": [],
    "awayAccurateCross": [],
    "homeDribble": [],
    "awwayDribble": [],
    "homeSuccessfulDribble": [],
    "awaySuccessfulDribble": [],
    "homePossesionLost": [],
    "awayPossesionLost": [],
    "homeDuelWon": [],
    "awayDuelWon": [],
    "homeAerialWon": [],
    "awayAerialWon": [],
    "homeTackle": [],
    "awayTackle": [],
    "homeInterception": [],
    "awayInterception": [],
    "homeClearance": [],
    "awayClearance": []
}

df = pd.DataFrame(dictionary)
df
# Out:
# Empty DataFrame
# Columns: [id, homeExpectedGoal, awayExpectedGoal, homeExpectedAssist, awayExpectedAssist, homeBallPosession, homeShotOnTarget, awayShotOnTarget, homeShotOffTarget, awayShotOffTarget, homeBlockedShot, awayBlockedShot, homeCorner, awayCorner, homeOffside, awayOffside, homeFoul, awayFoul, homeYellowCard, awayYellowCard, homeRedCard, awayRedCard, homeFreekick, awayFreekick, homeThrowIn, awayThrowIn, homeGoalkick, awayGoalkick, homeBigChance, awayBigChance, homeBigChanceMissed, awayBigChanceMissed, homeShotInsideBox, awayShotInsideBox, homeGoalSave, awayGoalSave, homeGoalPrevented, awayGoalPrevented, homePass, awayPass, homeAccuratePass, awayAccuratePass, homeLongPass, awayLongPass, homeAccurateLongPass, awayAccurateLongPass, homeCross, awayCross, homeAccurateCross, awayAccurateCross, homeDribble, awwayDribble, homeSuccessfulDribble, awaySuccessfulDribble, homePossesionLost, awayPossesionLost, homeDuelWon, awayDuelWon, homeAerialWon, awayAerialWon, homeTackle, awayTackle, homeInterception, awayInterception, homeClearance, awayClearance]
# Index: []
#
# [0 rows x 66 columns]

# %%
def getExpected(statisticsItems):
    homeExpectedGoal = 0
    awayExpectedGoal = 0
    homeExpectedAssist = 0
    awayExpectedAssist = 0
    
    for item in statisticsItems:
        if item["name"] == "Expected goals":
            homeExpectedGoal = item["home"]
            awayExpectedGoal = item["away"]
        if item["name"] == "Expected assists":
            homeExpectedAssist = item["home"]
            awayExpectedAssist = item["away"]  
            
    return [homeExpectedGoal, awayExpectedGoal, homeExpectedAssist, awayExpectedAssist]  

def getPossession(statisticsItems):
    homeBallPosession = 0
    for item in statisticsItems:
        if item["name"] == "Ball possession":
            homeBallPosession = int(item["home"][:-1])
            
    return [homeBallPosession]

def getShot(statisticsItems):
    homeShotOnTarget = 0
    awayShotOnTarget = 0
    homeShotOffTarget = 0
    awayShotOffTarget = 0
    homeBlockedShot = 0
    awayBlockedShot = 0   
    
    for item in statisticsItems:
        if item["name"] == "Shots on target":
            homeShotOnTarget = item["home"]
            awayShotOnTarget = item["away"]
        if item["name"] == "Shots off target":
            homeShotOffTarget = item["home"]
            awayShotOffTarget = item["away"] 
        if item["name"] == "Blocked shots":
            homeBlockedShot = item["home"]
            awayBlockedShot = item["away"] 
            
    return [homeShotOnTarget, awayShotOnTarget, homeShotOffTarget, awayShotOffTarget, homeBlockedShot, awayBlockedShot]

def getTVData(statisticsItems):
    homeCorner = 0
    awayCorner = 0
    homeOffside = 0
    awayOffside = 0
    homeFoul = 0
    awayFoul = 0
    homeYellowCard = 0
    awayYellowCard = 0
    homeRedCard = 0
    awayRedCard = 0
    homeFreekick = 0
    awayFreekick = 0
    homeThrowIn = 0
    awayThrowIn = 0
    homeGoalkick = 0
    awayGoalkick = 0  
    
    for item in statisticsItems:
        if item["name"] == "Corner kicks":
            homeCorner = item["home"]
            awayCorner = item["away"]
        if item["name"] == "Offsides":
            homeOffside = item["home"]
            awayOffside = item["away"] 
        if item["name"] == "Fouls":
            homeFoul = item["home"]
            awayFoul = item["away"]
        if item["name"] == "Yellow cards":
            homeYellowCard = item["home"]
            awayYellowCard = item["away"]
        if item["name"] == "Red cards":
            homeRedCard = item["home"]
            awayRedCard = item["away"] 
        if item["name"] == "Free kicks":
            homeFreekick = item["home"]
            awayFreekick = item["away"]
        if item["name"] == "Throw-ins":
            homeThrowIn = item["home"]
            awayThrowIn = item["away"]
        if item["name"] == "Goal kicks":
            homeGoalkick = item["home"]
            awayGoalkick = item["away"] 
            
    return [homeCorner, awayCorner, homeOffside, awayOffside, homeFoul, awayFoul, homeYellowCard, awayYellowCard, 
            homeRedCard, awayRedCard, homeFreekick, awayFreekick, homeThrowIn, awayThrowIn, homeGoalkick, awayGoalkick]
    
def getShotExtra(statisticsItems):
    homeBigChance = 0
    awayBigChance = 0
    homeBigChanceMissed = 0
    awayBigChanceMissed = 0
    homeShotInsideBox = 0
    awayShotInsideBox = 0
    homeGoalSave = 0
    awayGoalSave = 0
    homeGoalPrevented = 0
    awayGoalPrevented = 0
    
    for item in statisticsItems:
        if item["name"] == "Big chances":
            homeBigChance = item["home"]
            awayBigChance = item["away"]
        if item["name"] == "Big chances missed":
            homeBigChanceMissed = item["home"]
            awayBigChanceMissed = item["away"] 
        if item["name"] == "Shots inside box":
            homeShotInsideBox = item["home"]
            awayShotInsideBox = item["away"]
        if item["name"] == "Goalkeeper saves":
            homeGoalSave = item["home"]
            awayGoalSave = item["away"]
        if item["name"] == "Goals prevented":
            homeGoalPrevented = item["home"]
            awayGoalPrevented = item["away"]
            
    return [homeBigChance, awayBigChance, homeBigChanceMissed, awayBigChanceMissed,
            homeShotInsideBox, awayShotInsideBox, homeGoalSave, awayGoalSave, homeGoalPrevented, awayGoalPrevented]
    
def getPass(statisticsItems):
    homePass = 0
    awayPass = 0
    homeAccuratePass = 0
    awayAccuratePass = 0
    homeLongPass = 0
    awayLongPass = 0
    homeAccurateLongPass = 0
    awayAccurateLongPass = 0
    homeCross = 0
    awayCross = 0
    homeAccurateCross = 0
    awayAccurateCross = 0
    
    for item in statisticsItems:
        if item["name"] == "Passes":
            homePass = item["home"]
            awayPass = item["away"]
        if item["name"] == "Accurate passes":
            homeAccuratePass = item["home"].split(" ")[0]
            awayAccuratePass = item["away"].split(" ")[0]
        if item["name"] == "Long balls":
            homeAccurateLongPass = item["home"].split(" ")[0].split("/")[0]
            awayAccurateLongPass = item["away"].split(" ")[0].split("/")[0]
            homeLongPass = item["home"].split(" ")[0].split("/")[1]
            awayLongPass = item["away"].split(" ")[0].split("/")[1]
        if item["name"] == "Crosses":
            homeAccurateCross = item["home"].split(" ")[0].split("/")[0]
            awayAccurateCross = item["away"].split(" ")[0].split("/")[0]
            homeCross = item["home"].split(" ")[0].split("/")[1]
            awayCross = item["away"].split(" ")[0].split("/")[1]
            
    return [homePass, awayPass, homeAccuratePass, awayAccuratePass, homeLongPass, awayLongPass,
            homeAccurateLongPass, awayAccurateLongPass, homeCross, awayCross, homeAccurateCross, awayAccurateCross]
    
def getDuel(statisticsItems):
    homeDribble = 0
    awayDribble = 0
    homeSuccessfulDribble = 0
    awaySuccessfulDribble = 0
    homePossesionLost = 0
    awayPossesionLost = 0
    homeDuelWon = 0
    awayDuelWon = 0
    homeAerialWon = 0
    awayAerialWon = 0
    
    for item in statisticsItems:
        if item["name"] == "Dribbles":
            homeSuccessfulDribble = item["home"].split(" ")[0].split("/")[0]
            awaySuccessfulDribble = item["away"].split(" ")[0].split("/")[0]
            homeDribble = item["home"].split(" ")[0].split("/")[1]
            awayDribble = item["away"].split(" ")[0].split("/")[1]
        if item["name"] == "Possession lost":
            homePossesionLost = item["home"]
            awayPossesionLost = item["away"]
        if item["name"] == "Duels won":
            homeDuelWon = item["home"]
            awayDuelWon = item["away"]
        if item["name"] == "Aerials won":
            homeAerialWon = item["home"]
            awayAerialWon = item["away"]
            
    return [homeDribble, awayDribble, homeSuccessfulDribble, awaySuccessfulDribble, homePossesionLost,
            awayPossesionLost, homeDuelWon, awayDuelWon, homeAerialWon, awayAerialWon]
              
def getDefending(statisticsItems):
    homeTackle = 0
    awayTackle = 0
    homeInterception = 0
    awayInterception = 0
    homeClearance = 0
    awayClearance = 0
    
    for item in statisticsItems:
        if item["name"] == "Tackles":
            homeTackle = item["home"]
            awayTackle = item["away"]
        if item["name"] == "Interceptions":
            homeInterception = item["home"]
            awayInterception = item["away"]
        if item["name"] == "Clearances":
            homeClearance = item["home"]
            awayClearance = item["away"]
            
    return [homeTackle, awayTackle, homeInterception, awayInterception, homeClearance, awayClearance]

def getInfoFromGroup(groupList):
    info = []
    for group in groupList:
        if group["groupName"] == "Expected":
            info += getExpected(group["statisticsItems"])
        if group["groupName"] == "Possession":
            info += getPossession(group["statisticsItems"])
        if group["groupName"] == "Shots":
            info += getShot(group["statisticsItems"])
        if group["groupName"] == "TVData":
            info += getTVData(group["statisticsItems"])
        if group["groupName"] == "Shots extra":
            info += getShotExtra(group["statisticsItems"])
        if group["groupName"] == "Passes":
            info += getPass(group["statisticsItems"])
        if group["groupName"] == "Duels":
            info += getDuel(group["statisticsItems"])
        if group["groupName"] == "Defending":
            info += getDefending(group["statisticsItems"])
            
    info = [float(i) for i in info]
    return info

# %%
def get_match_id_from_dir(path):
    pattern = r"\d{8}"
    _id = re.findall(pattern, path)
    
    return _id[-1]

count = 0
for file in glob.glob("EPL 23-24\\*\\matches\\*\\*_statistic.json"):
    count += 1
    match_id = get_match_id_from_dir(file)
    with open(file, "r", encoding="utf-8") as f:
        data = json.load(f)
        if data["statistics"] is None:
            continue
        for info in data["statistics"]:
            if info["period"] == "1ST":
                groupList = info["groups"]
                info = [match_id] + getInfoFromGroup(groupList)
                df.loc[len(df)] = info
        
df
# Out:
#            id  homeExpectedGoal  awayExpectedGoal  homeExpectedAssist  \
# 0    11352251              0.32              0.28                0.48
# 1    11352255              1.30              0.57                0.89
# 2    11352250              0.08              0.74                0.10
# 3    11352253              2.13              0.04                0.72
# 4    11352252              1.37              0.43                1.09
# ..        ...               ...               ...                 ...
# 115  11352306              0.49              0.17                0.03
# 116  11352307              0.40              0.23                0.06
# 117  11352310              0.17              0.84                0.03
# 118  11352320              0.01              0.96                0.10
# 119  11352323              0.17              1.12                0.20
#
#      awayExpectedAssist  homeBallPosession  homeShotOnTarget  \
# 0                  0.03               84.0               3.0
# 1                  0.60               56.0               4.0
# 2                  0.78               66.0               2.0
# 3                  0.11               30.0               5.0
# 4                  0.57               71.0               3.0
# ..                  ...                ...               ...
# 115                0.21               16.0               3.0
# 116                0.19               41.0               0.0
# 117                0.67               26.0               1.0
# 118                0.53               38.0               0.0
# 119                0.18               48.0               3.0
#
#      awayShotOnTarget  homeShotOffTarget  awayShotOffTarget  ...  homeDuelWon  \
# 0                 0.0                2.0                1.0  ...         21.0
# 1                 2.0                1.0                3.0  ...         26.0
# 2                 2.0                1.0                7.0  ...         24.0
# 3                 0.0                3.0                1.0  ...         14.0
# 4                 1.0                8.0                3.0  ...         20.0
# ..                ...                ...                ...  ...          ...
# 115               1.0                3.0                2.0  ...         15.0
# 116               1.0                4.0                2.0  ...         29.0
# 117               3.0                2.0                6.0  ...         23.0
# 118               1.0                0.0                4.0  ...         18.0
# 119               2.0                0.0                4.0  ...         28.0
#
#      awayDuelWon  homeAerialWon  awayAerialWon  homeTackle  awayTackle  \
# 0           21.0            6.0            7.0         9.0         8.0
# 1           15.0            2.0            3.0        11.0         3.0
# 2           43.0            6.0           15.0        10.0        16.0
# 3           14.0            1.0            5.0         7.0         3.0
# 4           21.0            9.0            9.0         5.0         8.0
# ..           ...            ...            ...         ...         ...
# 115         22.0            4.0            8.0         7.0         4.0
# 116         16.0           11.0            6.0         7.0         5.0
# 117         18.0            5.0           10.0         9.0         4.0
# 118         32.0            3.0           12.0        14.0         7.0
# 119         27.0            3.0            2.0        12.0        10.0
#
#      homeInterception  awayInterception  homeClearance  awayClearance
# 0                 0.0               5.0            2.0           10.0
# 1                 5.0               6.0            7.0            8.0
# 2                 3.0               2.0            6.0           12.0
# 3                 5.0               0.0            7.0           10.0
# 4                 4.0               8.0            5.0           16.0
# ..                ...               ...            ...            ...
# 115               3.0               0.0           13.0            1.0
# 116               5.0               3.0            8.0           11.0
# 117               8.0               5.0           12.0            6.0
# 118               5.0               3.0            8.0           11.0
# 119               7.0               7.0           13.0            5.0
#
# [120 rows x 66 columns]

# %%
df.to_csv('match_statistic.csv', index=False)

# %% [markdown]
# ### 3. From h2h.json

# %%
import re
import glob
import pandas as pd
import json

dictionary = {
    "id": [],
    "previousHomeWin": [],
    "previousAwayWin": [],
    "previousDraw": [],
    "previousManagerHomeWin": [],
    "previousManagerAwayWin": [],
    "previousManagerDraw": []
}

df = pd.DataFrame(dictionary)
df
# Out:
# Empty DataFrame
# Columns: [id, previousHomeWin, previousAwayWin, previousDraw, previousManagerHomeWin, previousManagerAwayWin, previousManagerDraw]
# Index: []

# %%
def get_match_id_from_dir(path):
    pattern = r"\d{8}"
    _id = re.findall(pattern, path)
    
    return _id[-1]

for file in glob.glob("EPL 23-24\\*\\matches\\*\\*_h2h.json"):
    match_id = get_match_id_from_dir(file)
    with open(file, "r", encoding="utf-8") as f:
        data = json.load(f)
        if data is None:
            continue
        previousHomeWin = data.get("teamDuel", dict()).get("homeWins", 0)
        previousAwayWin = data.get("teamDuel", dict()).get("awayWins", 0)
        previousDraw = data.get("teamDuel", dict()).get("draws", 0)
        previousManagerHomeWin = data.get("managerDuel", dict()).get("homeWins", 0)
        previousManagerAwayWin = data.get("managerDuel", dict()).get("awayWins", 0)
        previousManagerDraw = data.get("managerDuel", dict()).get("draws", 0)
        
        df.loc[len(df)] = [match_id, previousHomeWin, previousAwayWin, previousDraw,
                           previousManagerHomeWin, previousManagerAwayWin, previousManagerDraw]

# %%
df.to_csv('match_h2h.csv', index=False)

# %% [markdown]
# ### 4. pregame_form.json

# %%
import re
import glob
import pandas as pd
import json

dictionary = {
    "id": [],
    "homeAvgRating": [],
    "homePosition": [],
    "homePoint": [],
    "homeForm": [],
    "awayAvgRating": [],
    "awayPosition": [],
    "awayPoint": [],
    "awayForm": []
}

df = pd.DataFrame(dictionary)
df
# Out:
# Empty DataFrame
# Columns: [id, homeAvgRating, homePosition, homePoint, homeForm, awayAvgRating, awayPosition, awayPoint, awayForm]
# Index: []

# %%
def char2Point(res):
    if res == 'L':
        return 0
    if res == 'D':
        return 1
    return 3

def form2Point(form):
    if form is None or form == "":
        return ""
    points = [char2Point(match) for match in form]
    return sum(points) / len(points)
        

def get_match_id_from_dir(path):
    pattern = r"\d{8}"
    _id = re.findall(pattern, path)
    
    return _id[-1]

for file in glob.glob("EPL 23-24\\*\\matches\\*\\*_pregame_form.json"):
    match_id = get_match_id_from_dir(file)
    with open(file, "r", encoding="utf-8") as f:
        data = json.load(f)
        if data is None:
            continue
        homeAvgRating = data.get("homeTeam", dict()).get("avgRating", "")
        homePosition = data.get("homeTeam", dict()).get("position", "")
        homePoint = data.get("homeTeam", dict()).get("value", "")
        homeForm = form2Point(data.get("homeTeam", dict()).get("form", ""))
        awayAvgRating = data.get("awayTeam", dict()).get("avgRating", "")
        awayPosition = data.get("awayTeam", dict()).get("position", "")
        awayPoint = data.get("awayTeam", dict()).get("value", "")
        awayForm = form2Point(data.get("awayTeam", dict()).get("form", ""))
        
        df.loc[len(df)] = [match_id, homeAvgRating, homePosition, homePoint, homeForm,
                           awayAvgRating, awayPosition, awayPoint, awayForm]

# %%
df.to_csv('match_pregame_form.csv', index=False)
